# %%
import pandas as pd

# %%
dataVg = pd.read_csv("vgsales.csv")

# %%
dataVg
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
dataVg["NA_prop"] = dataVg["NA_Sales"] / dataVg["Global_Sales"]
dataVg["EU_prop"] = dataVg["EU_Sales"] / dataVg["Global_Sales"]
dataVg["JP_prop"] = dataVg["JP_Sales"] / dataVg["Global_Sales"]
dataVg["Other_prop"] = dataVg["Other_Sales"] / dataVg["Global_Sales"]

# %%
japan_sales = dataVg["JP_prop"].sort_values(ascending=False)

# %%
list(japan_sales[1:10].index)
# Out:
# [14396, 11027, 14401, 8980, 14403, 14405, 8984, 14409, 4182]

# %%
dataVg.iloc[japan_sales[1:10].index]
# Out:
#         Rank                                          Name Platform    Year  \
# 14396  14399                            Otomedius Gorgeous     X360  2008.0
# 11027  11029       Jikkyou Powerful Pro Yakyuu 9 Ketteiban      PS2  2002.0
# 14401  14404                             Kiniro no Corda 3      PS2  2010.0
# 8980    8982  Dragon Ball Z: Idainaru Dragon Ball Densetsu      SAT  1995.0
# 14403  14406                     Darkstalkers Resurrection      PS3  2013.0
# 14405  14408                        Highschool Terra Story      SAT  1998.0
# 8984    8986                 Making History: The Great War      Wii  2010.0
# 14409  14412                        Suggoi! Arcana Heart 2      PS2  2009.0
# 4182    4184                        Clash of Elementalists       DS  2010.0
#
#            Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 14396    Shooter  Konami Digital Entertainment       0.0       0.0      0.03
# ...

# %%
japan_sales
# Out:
# 14704    1.0
# 14396    1.0
# 11027    1.0
# 14401    1.0
# 8980     1.0
#         ...
# 7166     0.0
# 7167     0.0
# 7168     0.0
# 7172     0.0
# 16597    0.0
# Name: JP_prop, Length: 16598, dtype: float64

# %%
japan_sales[0:11].index
# Out:
# Int64Index([14704, 14396, 11027, 14401, 8980, 14403, 14405, 8984, 14409, 4182,
#             11022],
#            dtype='int64')

# %%
dataVg
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
dataVg.iloc[japan_sales[0:11].index]
# Out:
#         Rank                                          Name Platform    Year  \
# 14704  14707                                  The Last Guy      PS3  2009.0
# 14396  14399                            Otomedius Gorgeous     X360  2008.0
# 11027  11029       Jikkyou Powerful Pro Yakyuu 9 Ketteiban      PS2  2002.0
# 14401  14404                             Kiniro no Corda 3      PS2  2010.0
# 8980    8982  Dragon Ball Z: Idainaru Dragon Ball Densetsu      SAT  1995.0
# 14403  14406                     Darkstalkers Resurrection      PS3  2013.0
# 14405  14408                        Highschool Terra Story      SAT  1998.0
# 8984    8986                 Making History: The Great War      Wii  2010.0
# 14409  14412                        Suggoi! Arcana Heart 2      PS2  2009.0
# 4182    4184                        Clash of Elementalists       DS  2010.0
# 11022  11024    Doraemon: Nobita to Midori no Kyojinden DS       DS  2008.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
dataVg["EU_Sales"]
# Out:
# 0        29.02
# 1         3.58
# 2        12.88
# 3        11.01
# 4         8.89
#          ...
# 16593     0.00
# 16594     0.00
# 16595     0.00
# 16596     0.01
# 16597     0.00
# Name: EU_Sales, Length: 16598, dtype: float64

# %%
dataVg["Global_Sales"]
# Out:
# 0        82.74
# 1        40.24
# 2        35.82
# 3        33.00
# 4        31.37
#          ...
# 16593     0.01
# 16594     0.01
# 16595     0.01
# 16596     0.01
# 16597     0.01
# Name: Global_Sales, Length: 16598, dtype: float64

# %%
dataVg["grafico"] = dataVg["EU_Sales"] > 10

# %%
plt.plot(dataVg["EU_Sales"][dataVg["grafico"] == True], label="Vendas Europa")
plt.plot(dataVg["Global_Sales"][dataVg["grafico"] == True], label="Vendas Globais")
plt.legend()
